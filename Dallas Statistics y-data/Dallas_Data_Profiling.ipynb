# %%
#pip install ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv(
    "/content/drive/MyDrive/Chinmay/Restaurant_and_Food_Establishment_Inspections__October_2016_to_Present__20240223.tsv",sep='\t'
)
# Out:
# <ipython-input-4-c7e8d04467b3>:1: DtypeWarning: Columns (95,97,98,99,101,102,103,105,106,107,109,110) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(

# %%
profile = ProfileReport(data, title="Dallas Restaurant Data")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_file("Dallas Restaurant Data.html")
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
