# %%
#pip install ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv(
    "/content/drive/MyDrive/Chinmay/Food_Inspections_20240223.tsv",sep='\t'
)

# %%
profile = ProfileReport(data, title="Chicago Restaurant Data")

# %%
sample_data = data.sample(frac=0.1)  # Adjust the fraction based on your dataset size and available memory

# Generate the profile report for the sampled DataFrame
profile = sample_data.profile_report()
profile.to_file("Chicago.html")
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
profile

# %%
profile.to_file("Chicago Restaurant Data.html")
